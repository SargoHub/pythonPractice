# %% [markdown]
# <a href="https://colab.research.google.com/github/SargoHub/pythonPractice/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# **PANDAS SERIES**

# %%
# using the Series() function
l=[1,2,'hello',4.55,9]
a=pd.Series(l)    # creating a pandas series using the Series() function
a
# Out:
# 0        1
# 1        2
# 2    hello
# 3     4.55
# 4        9
# dtype: object

# %%
a[2]  # printing any value
# Out:
# 'hello'

# %%
type(a[2])
# Out:
# str

# %%
# we can give custom index values as well
l2=[1,2,3,4,5]
s=pd.Series(l2,index=[8,9,10,11,12])  # index values can be passed as the argument in the Series() function
s
# Out:
# 8     1
# 9     2
# 10    3
# 11    4
# 12    5
# dtype: int64

# %% [markdown]
# **PANDAS DATAFRAME**

# %%
# it is 2D data structure like a table with rows and columns
d={'Name':['Virat','Gayle','ABD'],'Team':['RCB','RCB','RCB'],'Runs':[4500,5600,6000]}  # this is Dict type data
d
# Out:
# {'Name': ['Virat', 'Gayle', 'ABD'],
#  'Team': ['RCB', 'RCB', 'RCB'],
#  'Runs': [4500, 5600, 6000]}

# %%
f=pd.DataFrame(d)  # converting the dict data to pandas DataFrame table structure
f
# Out:
#     Name Team  Runs
# 0  Virat  RCB  4500
# 1  Gayle  RCB  5600
# 2    ABD  RCB  6000

# %%
f['Name']  # indexing
# Out:
# 0    Virat
# 1    Gayle
# 2      ABD
# Name: Name, dtype: object

# %%
f['Name'][1]
# Out:
# 'Gayle'

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS (EDA)**
# Cleaning the data and manipulating it before feeding to a ML model

# %% [markdown]
# read_csv() function to get the dataset to jupiter

# %%
# using the read_csv() function to get the dataset to Jupiter
df=pd.read_csv(r"/content/data (3) (1).csv")
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.head() # gives us the top 5 rows
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.tail() # gives the last 5 rows
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.head(11) # gives the top 11 rows
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3

# %%
df.sample(5) # to get any 5 random rows
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 143        45    122       149     335.4
# 102        90     90       100     500.0
# 12         60    106       128     345.3
# 10         60    103       147     329.3
# 140        60    108       135     390.0

# %%
df.shape  # will give the no. of rows and columns
# Out:
# (169, 4)

# %%
df.iloc[3] # gives the values for the row with index 3
# Out:
# Duration     45.0
# Pulse       109.0
# Maxpulse    175.0
# Calories    282.4
# Name: 3, dtype: float64

# %%
df.columns # gives the list of the column names
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
g=list(df.columns)
g
# Out:
# ['Duration', 'Pulse', 'Maxpulse', 'Calories']

# %%
# type casting example
t={1,5,9,7}
l=list(t)
l
l[2]=11
l
t=tuple(l)
t
# Out:
# (1, 5, 11, 7)

# %%
# info() function use
df.info() # gives the basic info about the dataset lik column names, data type, non null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %% [markdown]
# **EMPTY DATA/CELLS**

# %%
# isnull() function to find the null value
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
# dropping the null values using the dropna() function
df=df.dropna() # this drops the null values
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
df.shape
# Out:
# (164, 4)

# %% [markdown]
# filling the null value

# %%
# filling the null values
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df=df.fillna(650) # this will fill the value 650 at every null location in the complete data set

# %%
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
df=pd.read_csv(r"/content/data (3) (1).csv")

# %%
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %% [markdown]
# filling with the mean value

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
m=df['Calories'].mean()
m
# Out:
# 375.79024390243904

# %%
df=df.fillna(m)  # adds the mean value at the null locations
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %% [markdown]
# filling with the mode values

# %%
# in cases where the mean cannot work like strings, we can use the mode value (most occuring)

mo=df['Calories'].mode()[0]
mo
# df=df.fillna(mo) this will fill the null values with the mode value
# Out:
# 0    300.0
# Name: Calories, dtype: float64

# %%
df['Duration'].unique() # gives the unique values present in the column
# Out:
# array([ 60,  45,  30,  80,  20, 210, 160, 180, 150, 300,  90, 120, 270,
#         15,  25,  75])

# %%
df['Duration'].nunique() # gives the number of unique values in the column
# Out:
# 16

# %%
df['Duration'].value_counts() # gives the count of each unique value in the column
# Out:
# Duration
# 60     79
# 45     35
# 30     16
# 20      9
# 90      8
# 150     4
# 180     3
# 120     3
# 210     2
# 160     2
# 15      2
# 75      2
# 80      1
# 300     1
# 270     1
# 25      1
# Name: count, dtype: int64

# %% [markdown]
# **CHECKING FOR DUPLICATED ROWS**

# %%
df.duplicated().sum()
# Out:
# 7

# %%
# dropping the duplicated rows
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0
